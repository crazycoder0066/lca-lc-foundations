# %%
from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "ollama:qwen2.5:7b"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='3e1d5aea-547a-4ce9-8a23-5ed8521c06ac'),
#               AIMessage(content='Hello Seán! Nice to meet you. Green is a wonderful color—many find it peaceful and refreshing. Is there anything specific about the color green that you particularly enjoy, or do you have any favorite green things?', additional_kwargs={}, response_metadata={'model': 'qwen2.5:7b', 'created_at': '2026-06-04T10:58:47.273403851Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5194572536, 'load_duration': 4495349086, 'prompt_eval_count': 41, 'prompt_eval_duration': 31684463, 'eval_count': 45, 'eval_duration': 628397373, 'logprobs': None, 'model_name': 'qwen2.5:7b', 'model_provider': 'ollama'}, id='lc_run--019e9249-0f1d-76e3-9079-8043cd7e4e4a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 45, 'total_tokens': 86})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='b27a6dc8-4c7e-4bfc-ac56-cae830477e3c'),
#               AIMessage(content="I'm sorry, but I don't have any information about your favorite color as we haven't discussed this before. Could you tell me what your favorite color is, or would you like to take a guess based on common preferences?", additional_kwargs={}, response_metadata={'model': 'qwen2.5:7b', 'created_at': '2026-06-04T10:58:54.159811959Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1099660218, 'load_duration': 41219152, 'prompt_eval_count': 35, 'prompt_eval_duration': 126535328, 'eval_count': 47, 'eval_duration': 884438457, 'logprobs': None, 'model_name': 'qwen2.5:7b', 'model_provider': 'ollama'}, id='lc_run--019e9249-3a03-72d0-8be1-c187134f9435-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 35, 'output_tokens': 47, 'total_tokens': 82})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "ollama:qwen2.5:7b",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='f0cbac67-8a53-4cbd-8980-67503b1a1b5b'),
#               AIMessage(content="Hello Seán! Nice to meet you. Green is a lovely color; it's associated with nature, growth, and harmony. Is there anything specific about green that you particularly like or do you have any favorite green-related activities or places?", additional_kwargs={}, response_metadata={'model': 'qwen2.5:7b', 'created_at': '2026-06-04T12:20:54.985431289Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5980871082, 'load_duration': 5191784829, 'prompt_eval_count': 41, 'prompt_eval_duration': 30633015, 'eval_count': 49, 'eval_duration': 711562752, 'logprobs': None, 'model_name': 'qwen2.5:7b', 'model_provider': 'ollama'}, id='lc_run--019e9294-3cea-78e2-9548-8639fd95bc04-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 49, 'total_tokens': 90})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='f0cbac67-8a53-4cbd-8980-67503b1a1b5b'),
#               AIMessage(content="Hello Seán! Nice to meet you. Green is a lovely color; it's associated with nature, growth, and harmony. Is there anything specific about green that you particularly like or do you have any favorite green-related activities or places?", additional_kwargs={}, response_metadata={'model': 'qwen2.5:7b', 'created_at': '2026-06-04T12:20:54.985431289Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5980871082, 'load_duration': 5191784829, 'prompt_eval_count': 41, 'prompt_eval_duration': 30633015, 'eval_count': 49, 'eval_duration': 711562752, 'logprobs': None, 'model_name': 'qwen2.5:7b', 'model_provider': 'ollama'}, id='lc_run--019e9294-3cea-78e2-9548-8639fd95bc04-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 49, 'total_tokens': 90}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='f3eaeeda-687d-44ba-845e-d24badc150ea'),
#               AIMessage(content="Your favorite color is green! It's great to hear that you enjoy the vibrant hues of green. If you have any more questions or want to chat about anything else, feel free to ask!", additional_kwargs={}, response_metadata={'model': 'qwen2.5:7b', 'created_at': '2026-06-04T12:21:01.373898724Z', 'done': True, 'done_reason': 'stop', 'total_duration': 850318200, 'load_duration': 43370147, 'prompt_eval_count': 105, 'prompt_eval_duration': 51055460, 'eval_count': 40, 'eval_duration': 717702572, 'logprobs': None, 'model_name': 'qwen2.5:7b', 'model_provider': 'ollama'}, id='lc_run--019e9294-69ea-7a30-b1d3-20fd9093b545-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 105, 'output_tokens': 40, 'total_tokens': 145})]}
