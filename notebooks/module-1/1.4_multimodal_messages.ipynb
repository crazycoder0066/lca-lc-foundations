# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='ollama:qwen2.5:7b',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)
# Out:
# /home/robbie/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/checkpoint/serde/encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The capital of The Moon, in this fictional setting, is called Luna New York, or LNY for short. Here's a brief overview to get you started:
#
# ### Name: Luna New York (LNY)
#
# #### Location and Layout:
# - **Location**: Luna New York is situated on the Mare Imbrium region of the moon, known as the Sea of Rains.
# - **Layout**: The city spans across the crater edges with advanced infrastructure built into the lunar surface. It features a mix of modern glass-and-metals structures and more traditional domed buildings that blend seamlessly with the lunar landscape.
#
# #### Key Attractions:
# 1. **Luna Central Park**: A spacious, well-lit park that serves as the heart of LNY, featuring artificial grass fields, lakes with water brought in from asteroids, and large trees genetically engineered to thrive on moonlight.
# 2. **The Moon Tower**: A colossal structure that houses the highest point observatory for lunar and space exploration.
# 3. **Luna Harbor**: An artificial harbor created using materials from nearby craters, where cargo ships and spaceships dock.
#
# #### Culture:
# - **Diverse Population**: A mix of humans from various Earth nations, as well as immigrants from other moons and planets within the Solar System.
# - **Cultural Festivals**: Celebrations include a Moon Harvest Festival with traditional dances and music, and an International Lunar Art Exhibition showcasing art from different cultures adapted to lunar conditions.
#
# #### Technology:
# - **Advanced Lighting Systems**: Utilizes solar panels integrated into the city's architecture for constant lighting without moonlight.
# - **Environmental Control**: Uses AI-driven systems to manage temperature and air quality in open spaces due to the lack of a protective atmosphere.
# - **Transportation**: Features personal levitation vehicles (PLVs) and lunar monorail systems that connect major points within the city.
#
# #### Governance:
# - **Luna Council**: Comprises representatives from various sectors including government, scientific research, and commercial enterprises. They oversee policies and projects for the sustainable development of LNY.
# - **Environmental and Safety Departments**: Work together to ensure the moon’s environment remains as pristine as possible while accommodating the needs of its inhabitants.
#
# #### Challenges:
# - **Resource Management**: The city faces challenges in managing resources like water, oxygen, and energy sustainably.
# - **Sustainability Initiatives**: Constant efforts are made to recycle waste and utilize local materials for construction and manufacturing.
#
# This capital city serves as a hub of innovation, culture, and exploration, setting the stage for your science fiction narrative.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon.png', 'type': 'image/png', 'size': 358916, 'content': <memory at 0x78407efeab00>, 'last_modified': datetime.datetime(2026, 6, 4, 3, 2, 55, 632000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Certainly! Let's imagine that "img-0" is an image of a grand and futuristic capital city called **Aeris Nova**. Here’s what Aeris Nova might look like:
#
# ---
#
# ### Name: Aeris Nova
#
# #### Location:
# Situated at the confluence of two rivers on a verdant, bioluminescent planet, Aeris Nova stands as a beacon of innovation and progress in the galaxy. The planet, known for its serene blue skies and vibrant flora, provides a unique backdrop to this bustling metropolis.
#
# #### Architecture:
# Aeris Nova is renowned for its floating architecture, which combines traditional Earth-like structures with advanced alien technologies. Buildings are often levitated using anti-gravity technology, creating an impression of fluidity and grace as they seem to move effortlessly above the ground. The cityscape is a harmonious blend of sleek metallic towers, vibrant bioluminescent gardens, and sprawling green spaces.
#
# #### Transportation:
# The transportation system in Aeris Nova is highly advanced and eco-friendly. Hovering shuttles and personal hovercrafts crisscross the sky, while subterranean rail systems connect different districts underground. High-speed maglev trains zip through dedicated tracks, offering fast transit between key areas of the city.
#
# #### Culture:
# Aeris Nova is a melting pot of cultures from across the galaxy, with citizens representing over 500 planetary species. The city hosts numerous cultural festivals and events throughout the year, celebrating diversity and fostering interstellar unity. Public spaces are filled with art installations by various artists, showcasing their unique perspectives.
#
# #### Government:
# The government of Aeris Nova is a democratic council elected by its citizens. The council is divided into several departments, each responsible for managing different aspects of city life—such as education, healthcare, infrastructure, and environmental sustainability. Transparency and public participation are central to the governance model.
#
# #### Notable Attractions:
# - **EcoSphere Park**: A massive, biologically diverse park where visitors can experience various flora and fauna from across the galaxy.
# - **Lumina Tower**: The tallest building in Aeris Nova, offering breathtaking views of the city at night. Its exterior glows with a mesmerizing light show that changes patterns based on weather conditions or public events.
# - **Galactic Marketplace**: A bustling bazaar where traders from various planets gather to sell their wares and exchange goods, creating a vibrant hub of commerce.
#
# #### Challenges:
# Despite its advancements, Aeris Nova faces challenges such as managing the growing population and preserving natural resources. Efforts are being made through sustainable practices and innovative technologies to ensure the city remains both prosperous and eco-friendly.
#
# ---
#
# Aeris Nova is more than just a capital; it's a symbol of hope and progress in the galaxy, embodying the ideals of unity, innovation, and environmental stewardship.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
