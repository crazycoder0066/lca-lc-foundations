# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# False

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="ollama:qwen2.5:7b")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon does not have any capitals because it is not inhabited and has no governmental structure like Earth. The concept of a capital city is relevant to human settlements with administrative divisions, which do not exist on the Moon at present. However, if humans establish permanent settlements or colonies there in the future, they might consider naming a central hub as a capital, but this is purely speculative at this point.', additional_kwargs={}, response_metadata={'model': 'qwen2.5:7b', 'created_at': '2026-06-04T09:49:04.974528695Z', 'message': {'role': 'assistant', 'content': ''}, 'done': True, 'done_reason': 'stop', 'total_duration': 6054328930, 'load_duration': 4753207268, 'prompt_eval_count': 37, 'prompt_eval_duration': 30366124, 'eval_count': 80, 'eval_duration': 1200419559}, id='lc_run--019e9209-2f1e-7483-a256-7fb5a3bd29a0-0', tool_calls=[], invalid_tool_calls=[])

# %%
print(response.content)

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'created_at': '2026-06-04T09:49:04.974528695Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 80,
#  'eval_duration': 1200419559,
#  'load_duration': 4753207268,
#  'message': {'content': '', 'role': 'assistant'},
#  'model': 'qwen2.5:7b',
#  'prompt_eval_count': 37,
#  'prompt_eval_duration': 30366124,
#  'total_duration': 6054328930}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="ollama:qwen2.5:7b",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not have any cities or capitals because it is not inhabited and has no governmental structures. The concept of a capital city applies to inhabited planets and celestial bodies that support significant human populations with defined governance. Currently, all human activities on the Moon are part of space exploration and research conducted by various countries and organizations. If there were ever permanent human settlements on the Moon in the future, they would need to be established according to the principles of international law, including the Moon Agreement of 1979.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[8], line 3
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
# ----> 3 model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
#       5 response = model.invoke("What's the capital of the Moon?")
#       6 print(response.content)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:2269, in ChatGoogleGenerativeAI.__init__(self, **kwargs)
#    2262         suggestion = (
#    2263             f" Did you mean: '{suggestions[0]}'?" if suggestions else ""
#    2264         )
#    2265         logger.warning(
#    2266             f"Unexpected argument '{arg}' "
#    2267             f"provided to ChatGoogleGenerativeAI.{suggestion}"
#    2268         )
# -> 2269 super().__init__(**kwargs)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/load/serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/pydantic/main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for ChatGoogleGenerativeAI
#   Value error, API key required for Gemini Developer API. Provide api_key parameter or set GOOGLE_API_KEY/GEMINI_API_KEY environment variable. [type=value_error, input_value={'model': 'gemini-2.5-fla...te', 'model_kwargs': {}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/value_error

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)
# Out:
# /home/robbie/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/checkpoint/serde/encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("ollama:qwen2.5:7b")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='c66c4957-d291-4313-9505-2ea9f974b507'),
#               AIMessage(content='The Moon does not have any cities or capitals because it is not inhabited and does not have a government in the way that Earth does. However, if we were to imagine a lunar civilization, the capital might be located at one of the lunar poles where conditions are more favorable for habitation due to the presence of water ice. As of now, all human space missions have only been temporary visits with no permanent structures or governance established on the Moon.', additional_kwargs={}, response_metadata={'model': 'qwen2.5:7b', 'created_at': '2026-06-04T09:59:08.652557209Z', 'message': {'role': 'assistant', 'content': ''}, 'done': True, 'done_reason': 'stop', 'total_duration': 1746249972, 'load_duration': 58959144, 'prompt_eval_count': 37, 'prompt_eval_duration': 124560047, 'eval_count': 90, 'eval_duration': 1484387679}, id='lc_run--019e9212-760a-7f02-b9b4-13a407e48e17-0', tool_calls=[], invalid_tool_calls=[])]}

# %%
print(response['messages'][-1].content)

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='b2a8d997-050c-48f4-bb1e-b662d49eedb3'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='d1159276-562b-4b65-b3b7-efb141bce720', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='6d2a3d78-2353-4965-8f34-0556872a8a0d'),
#               AIMessage(content="Luna City is a fictional concept and not an actual city on the Moon. However, let's explore some ideas and concepts related to this notion:\n\n1. **Purpose**: In science fiction or future scenarios, Luna City might be established for various purposes such as scientific research, resource extraction, tourism, or even permanent human habitation.\n\n2. **Location**: The exact location could vary depending on the story or scenario. Common choices include locations at lower latitudes where there's more sunlight and potentially accessible resources like water ice in permanently shadowed craters.\n\n3. **Infrastructure**: Luna City might feature habitats built into lunar caves, known as lava tubes, to provide protection from radiation and extreme temperature fluctuations. It could also have solar panels for energy, air recycling systems, and advanced life support technology.\n\n4. **Culture and Community**: In a more developed scenario, Luna City could house a diverse community of astronauts, scientists, engineers, and possibly even families. These residents might engage in various activities ranging from research projects to leisure time with moon views and unique experiences.\n\n5. **Governance**: Depending on the context, Luna City could be governed by an international organization, a private company, or perhaps a self-governing community with its own laws and regulations.\n\nWhile we currently do not have any established permanent human settlements on the Moon, such concepts are being actively discussed as part of plans for future lunar exploration and habitation. If you're interested in learning more about real-world plans for lunar bases, NASA's Artemis program or China’s Chang'e missions could be good places to start.", additional_kwargs={}, response_metadata={'model': 'qwen2.5:7b', 'created_at': '2026-06-04T09:59:26.644459859Z', 'message': {'role': 'assistant', 'content': ''}, 'done': True, 'done_reason': 'stop', 'total_duration': 6399867713, 'load_duration': 43370633, 'prompt_eval_count': 64, 'prompt_eval_duration': 207736179, 'eval_count': 320, 'eval_duration': 5905547058}, id='lc_run--019e9212-b5b3-70f0-aad1-85b0cb8845c0-0', tool_calls=[], invalid_tool_calls=[])]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional concept often explored in science fiction and can take on many different forms depending on the story or narrative. However, I can provide you with a general overview based on common themes found in depictions of lunar capitals.
#
# ### Overview
#
# Luna City, as the capital city of the Moon, is typically depicted as a hub for scientific research, governmental operations, and commercial activities related to space exploration and habitation. Given that the moon lacks an atmosphere, water, and other essential resources, Luna City would be designed with advanced technology to support human life.
#
# ### Architecture
#
# - **Modular Design:** The city might feature modular structures made from lunar regolith (moon soil) or materials brought from Earth. These buildings are likely to have pressurized environments to protect inhabitants from the vacuum of space.
#
# - **Sustainability:** Buildings and infrastructure would be focused on sustainability, using renewable energy sources like solar power, which is abundant in the lunar environment.
#
# ### Layout
#
# - **Central Plaza:** A central plaza might serve as a gathering place for citizens, featuring public buildings such as government offices, museums, and research facilities.
#
# - **Residential Areas:** Separate residential zones would house families, scientists, engineers, and other residents. These areas could include living quarters with amenities similar to those on Earth.
#
# - **Research Facilities:** Specialized labs and observatories dedicated to lunar science, astronomy, and space exploration would be prominent features of Luna City.
#
# ### Technology
#
# - **Advanced Life Support Systems:** The city likely employs advanced life support systems to recycle air, water, and waste. These technologies are crucial for maintaining a livable environment.
#
# - **Transportation:** Space elevators or other advanced transportation systems might connect Luna City with other lunar facilities or even Earth. Ground transport within the city would probably use wheeled vehicles adapted for low-gravity conditions.
#
# ### Culture
#
# - **Community Life:** Despite its technological focus, Luna City often features a vibrant community life, with cultural events, sports, and leisure activities that promote social cohesion.
#
# - **Educational Institutions:** Schools and universities offering courses in space science, engineering, and related fields would play an important role in the city's intellectual landscape.
#
# ### Challenges
#
# - **Resource Management:** Efficient management of resources such as water, food, and energy is a significant challenge for Luna City. Recycling technologies and sustainable practices are crucial.
#
# - **Psychological Well-being:** Living in space can be isolating, so maintaining mental health through social activities, hobbies, and community support systems is essential.
#
# ### Conclusion
#
# Luna City serves not only as the administrative center of the Moon but also as a symbol of human ingenuity and ambition. Its design and functionality reflect the complexities involved in creating a habitable environment beyond Earth's atmosphere while highlighting the importance of collaboration and innovation in space exploration.
#
# Of course, specific details about Luna City can vary widely depending on the context or narrative in which it is featured. If you have any particular aspects or scenarios you'd like to explore further, feel free to ask!
